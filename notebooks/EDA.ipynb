# %% [markdown]
# # Sprint 4 Project EDA

# %% [markdown]
# The purpose of this notebook is to perform EDA on some car advertisement data to see what sort of graphs would be interesting to make for a web application.

# %% [markdown]
# ## Set Up Environment and Data

# %% [markdown]
# ### Import and Read

# %%
# import pkgs
import pandas as pd
import plotly.express as px
import altair as alt
import streamlit as st

# %%
# read data
car_df = pd.read_csv('~/TripleTen/Sprint_4/Sprint_4_Project/vehicles_us.csv')
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
car_df.sample(50)
# Out:
#        price  model_year                     model  condition  cylinders  \
# 48803   4995         NaN            toyota 4runner       good        8.0
# 15651   3000      2005.0         gmc sierra 2500hd       fair        8.0
# 31737   5490      2008.0                ford f-150       good        6.0
# 24978   9750      2012.0  chevrolet silverado 1500   like new        8.0
# 32106   6500      1994.0             jeep wrangler  excellent        4.0
# 4944    9399      2015.0             ford focus se   like new        4.0
# 33229   9999      2003.0         cadillac escalade       good        8.0
# 11985  33995      2013.0   jeep wrangler unlimited  excellent        6.0
# 16547  15500      2017.0               ford escape       good        4.0
# 33165   6495      2012.0              toyota prius  excellent        4.0
# 13772   6995      2005.0              dodge dakota  excellent        8.0
# 6968   32988      2016.0           chevrolet tahoe   like new        8.0
# 14781   5750      2014.0             ford focus se       good        4.0
# 15439  16500      2013.0       chevrolet silverado       good        8.0
# 46935  24825      2017.0              nissan rogue   like new        4.0
# 16982   2300      1996.0               ford ranger       good        6.0
# 36083   7750      2011.0           toyota camry le  excellent        4.0
# 22552   5900      2001.0       chevrolet silverado  excellent        8.0
# 26711   7990      2006.0            ford econoline       good        8.0
# 7355   11500      2014.0               honda civic       good        4.0
# 25986  13980      2018.0            hyundai sonata  excellent        NaN
# 37809  24000      2005.0         gmc sierra 2500hd  excellent        8.0
# 1490    4500      2012.0          volkswagen jetta  excellent        4.0
# 35498  23950      2015.0                gmc sierra  excellent        8.0
# 3103   21900      2013.0  ford mustang gt coupe 2d       good        NaN
# 40417   9999      2004.0             jeep wrangler  excellent        6.0
# 11290   6490      2012.0           toyota camry le  excellent        4.0
# 10894   9500      2015.0            hyundai sonata  excellent        NaN
# 49026  10995      2011.0  chevrolet silverado 1500       good        NaN
# 20221  10995      2017.0             nissan altima  excellent        4.0
# 43179  11000      2007.0       chevrolet silverado   like new        8.0
# 9811    5995      2004.0           chevrolet tahoe       good        8.0
# 13843  18990      2012.0                  ram 1500  excellent        8.0
# 20288   4795         NaN           toyota camry le       fair        4.0
# 14224   3995      2012.0            honda civic lx       good        4.0
# 11522    800      2000.0                ford focus       fair        4.0
# 30060   9450      2015.0           nissan frontier  excellent        6.0
# 20545   8495      2012.0               honda civic       good        4.0
# 7854    3200      2004.0        chevrolet suburban       good        8.0
# 29894  11000      2008.0             toyota tacoma       good        6.0
# 40964   6599      2007.0              honda accord  excellent        6.0
# 31782   9900      2014.0               ford fusion  excellent        4.0
# 42024   6000      2007.0                ford f-150  excellent        8.0
# 36780   9900      2016.0                ford f-250       fair        8.0
# 26465  16400      2011.0         cadillac escalade       good        8.0
# 8289   12000      2003.0             jeep wrangler       good        6.0
# 6187    6500      2012.0           chevrolet cruze  excellent        4.0
# 26381  29900      2012.0             ford f-350 sd       good        8.0
# 49063   8950      2013.0             nissan altima  excellent        NaN
# 34005  32000      2017.0                ford f-150  excellent        NaN
#
#          fuel  odometer transmission         type paint_color  is_4wd  \
# 48803     gas  250000.0    automatic          SUV        grey     1.0
# 15651     gas  120000.0    automatic        truck       brown     1.0
# 31737     gas  181761.0    automatic        truck       white     NaN
# 24978     gas  145000.0    automatic       pickup         NaN     1.0
# 32106     gas     175.0       manual  convertible         red     1.0
# 4944      gas   43143.0    automatic        sedan         red     NaN
# 33229     gas  122300.0    automatic          SUV       white     1.0
# 11985     gas   69889.0    automatic          SUV         NaN     1.0
# 16547     gas   50160.0    automatic          SUV       brown     1.0
# 33165  hybrid  112000.0    automatic    hatchback         NaN     NaN
# 13772     gas  132000.0    automatic       pickup         NaN     1.0
# 6968      gas   74653.0    automatic          SUV       black     NaN
# 14781     gas  101000.0    automatic        sedan       white     NaN
# 15439     gas   87000.0    automatic        truck        blue     NaN
# 46935     gas   26882.0    automatic          SUV       black     1.0
# 16982     gas  165000.0    automatic       pickup        blue     NaN
# 36083     gas  119000.0    automatic        sedan       black     NaN
# 22552     gas  202000.0    automatic       pickup         NaN     1.0
# 26711     gas  105429.0    automatic          van       white     NaN
# 7355      gas   59300.0    automatic        coupe         NaN     NaN
# 25986     gas   77719.0    automatic        sedan      silver     NaN
# 37809  diesel   77410.0    automatic       pickup       white     1.0
# 1490      gas       NaN    automatic        sedan         red     NaN
# 35498     gas  127700.0    automatic          van       white     NaN
# 3103      gas   51056.0        other        coupe      silver     NaN
# 40417     gas  132029.0    automatic          SUV      custom     1.0
# 11290     gas  149295.0    automatic        sedan         NaN     NaN
# 10894   other   31429.0    automatic        other      silver     NaN
# 49026     gas  173659.0    automatic        truck       white     1.0
# 20221     gas   75708.0    automatic        sedan      silver     NaN
# 43179     gas  160000.0    automatic        truck       white     1.0
# 9811      gas  212034.0    automatic          SUV       black     1.0
# 13843     gas  140742.0    automatic       pickup       black     1.0
# 20288     gas  152000.0    automatic        sedan        blue     NaN
# 14224     gas  170000.0    automatic        sedan       green     NaN
# 11522     gas   85777.0    automatic        sedan         red     NaN
# 30060     gas  142719.0    automatic        truck       white     1.0
# 20545     gas  133633.0    automatic        sedan        grey     NaN
# 7854      gas  161152.0    automatic          SUV        grey     NaN
# 29894     gas  240000.0    automatic        truck      silver     1.0
# 40964     gas  105000.0    automatic        sedan       black     NaN
# 31782     gas   80284.0    automatic        sedan       white     NaN
# 42024     gas  159000.0    automatic        truck         NaN     NaN
# 36780  diesel  199000.0    automatic        truck        grey     1.0
# 26465     gas  155810.0    automatic          SUV       black     1.0
# 8289      gas   90100.0    automatic          SUV         NaN     1.0
# 6187      gas   93000.0    automatic        sedan       black     NaN
# 26381     gas       NaN    automatic        truck         red     1.0
# 49063     gas   96000.0    automatic        sedan       black     NaN
# 34005     gas   95800.0    automatic       pickup         red     1.0
#
#       date_posted  days_listed
# 48803  2019-01-18           43
# 15651  2019-03-31           60
# 31737  2018-05-14            6
# 24978  2018-07-16            8
# 32106  2018-06-27           14
# 4944   2018-07-04           25
# 33229  2018-05-27           68
# 11985  2018-07-30           31
# 16547  2019-02-12          137
# 33165  2019-04-09           56
# 13772  2018-07-02           17
# 6968   2018-08-29           45
# 14781  2019-03-31           43
# 15439  2018-07-06           45
# 46935  2018-07-17           10
# 16982  2018-07-15           26
# 36083  2019-03-11           63
# 22552  2019-04-17           50
# 26711  2019-04-09           37
# 7355   2018-10-31            3
# 25986  2019-01-23           16
# 37809  2019-01-09           31
# 1490   2018-12-20           47
# 35498  2018-12-15           33
# 3103   2019-01-05           18
# 40417  2018-11-01           45
# 11290  2018-07-12           43
# 10894  2018-05-25           32
# 49026  2018-09-06           29
# 20221  2019-03-30            5
# 43179  2019-03-11           15
# 9811   2019-02-03           56
# 13843  2018-10-31           96
# 20288  2019-04-09            7
# 14224  2018-07-21           95
# 11522  2019-03-09           30
# 30060  2019-01-18           73
# 20545  2018-12-11           41
# 7854   2019-03-20           75
# 29894  2018-06-22           28
# 40964  2018-05-01           38
# 31782  2018-10-23           17
# 42024  2018-05-02           26
# 36780  2018-12-09           42
# 26465  2019-03-26           35
# 8289   2018-10-27           36
# 6187   2018-07-18           42
# 26381  2018-11-11           48
# 49063  2018-12-15          110
# 34005  2018-09-08           18

# %% [markdown]
# Some ideas: parse out make and model separately; parse out post year, month, day separately.

# %% [markdown]
# ### Clean Up Duplicates and Nulls

# %%
# Check for Dups
car_df.duplicated().unique()
# Out:
# array([False])

# %%
# Clean up price column
car_df['price'].describe()
# Out:
# count     51525.000000
# mean      12132.464920
# std       10040.803015
# min           1.000000
# 25%        5000.000000
# 50%        9000.000000
# 75%       16839.000000
# max      375000.000000
# Name: price, dtype: float64

# %%
car_df[car_df['price'] == 1]['price'].count()
# Out:
# 798

# %% [markdown]
# It is unknown what a price of 1 means. It could be that some of these cars were sold at 1 dollar, but not likely 798 of them.

# %%
car_df.groupby('price')['cylinders'].value_counts().head(20)
# Out:
# price  cylinders
# 1      10.0         295
#        6.0          172
#        8.0          171
#        4.0           88
#        3.0            1
# 3      6.0            1
# 5      6.0            1
# 6      8.0            1
# 9      4.0            1
# 10     4.0            1
# 11     8.0            1
# 12     4.0            2
#        6.0            1
# 15     8.0            3
# 20     8.0            1
# 24     10.0           1
# 25     6.0            1
#        8.0            1
# 28     8.0            1
# 32     4.0            1
# Name: count, dtype: int64

# %% [markdown]
# As suspected, the sale of cars at such low prices seems very uncommon. Articles on the subject say that online marketplaces have sellers with such listings as a search trick, to get their car to the top of the cheapest car search list, and then in the sale description confess this isn't the actual price of the car, it's a "listing fee" or something like that (the algorithm does catch some of these and removes them). Perusing the dates posted and days listed columns suggest that these cars are not all sold on the same day, these are just listings, so the 1 dollar trick is probably at play here. Take Note: a histogram of overall prices might be good to look at to see how many of these listings there are.

# %% [markdown]
# The model year is pretty straightforward, there are a few nulls. This most likely means the model year is unknown, but it won't do to replace these nulls with a string, it should be replaced with an integer that won't be confused with a known model year. They didn't drive cars in year 1.

# %%
car_df['model_year'] = car_df['model_year'].fillna(1).astype('int64')
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 5.1+ MB

# %%
car_df['cylinders'].value_counts()
# Out:
# cylinders
# 8.0     15844
# 6.0     15700
# 4.0     13864
# 10.0      549
# 5.0       272
# 3.0        34
# 12.0        2
# Name: count, dtype: int64

# %% [markdown]
# Likewise, there are no cars with a 1-cylinder engine.

# %%
car_df['cylinders'] = car_df['cylinders'].fillna(1).astype('int64')
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 5.1+ MB

# %%
car_df['odometer'].describe()
# Out:
# count     43633.000000
# mean     115553.461738
# std       65094.611341
# min           0.000000
# 25%       70000.000000
# 50%      113000.000000
# 75%      155000.000000
# max      990000.000000
# Name: odometer, dtype: float64

# %% [markdown]
# Let's set the unlisted odometer readings to -1.

# %%
car_df['odometer'] = car_df['odometer'].fillna(-1).astype('int64')
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  int64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# Paint color is all strings, and should be so, thus the nulls should be read as unlisted.

# %%
car_df['paint_color'] = car_df['paint_color'].fillna('unlisted')
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  int64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 5.1+ MB

# %%
car_df['is_4wd'].value_counts()
# Out:
# is_4wd
# 1.0    25572
# Name: count, dtype: int64

# %% [markdown]
# The nulls could mean either that the car is not 4wd, or it is unlisted. These should be converted to zero.

# %%
car_df['is_4wd'] = car_df['is_4wd'].fillna(0).astype('int64')
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  int64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  int64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: int64(6), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# ### Sophisticate Data

# %%
#parse out make and model
car_df['make'] = car_df['model'].str.split().str[0]
car_df['make'].value_counts()
# Out:
# make
# ford             12672
# chevrolet        10611
# toyota            5445
# honda             3485
# ram               3316
# jeep              3281
# nissan            3208
# gmc               2378
# subaru            1272
# dodge             1255
# hyundai           1173
# volkswagen         869
# chrysler           838
# kia                585
# cadillac           322
# buick              271
# bmw                267
# acura              236
# mercedes-benz       41
# Name: count, dtype: int64

# %%
#Parse out Year, Month, Day
car_df['date_posted'] = pd.to_datetime(car_df['date_posted'])
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  int64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  int64
#  11  date_posted   51525 non-null  datetime64[ns]
#  12  days_listed   51525 non-null  int64
#  13  make          51525 non-null  object
# dtypes: datetime64[ns](1), int64(6), object(7)
# memory usage: 5.5+ MB

# %%
car_df['year_posted'] = car_df['date_posted'].dt.year
car_df['month_posted'] = car_df['date_posted'].dt.month
car_df['day_posted'] = car_df['date_posted'].dt.day
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  int64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  int64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  int64
#  11  date_posted   51525 non-null  datetime64[ns]
#  12  days_listed   51525 non-null  int64
#  13  make          51525 non-null  object
#  14  year_posted   51525 non-null  int32
#  15  month_posted  51525 non-null  int32
#  16  day_posted    51525 non-null  int32
# dtypes: datetime64[ns](1), int32(3), int64(6), object(7)
# memory usage: 6.1+ MB

# %%
col = car_df.pop('make')
car_df.insert(2, 'make', col)
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   make          51525 non-null  object
#  3   model         51525 non-null  object
#  4   condition     51525 non-null  object
#  5   cylinders     51525 non-null  int64
#  6   fuel          51525 non-null  object
#  7   odometer      51525 non-null  int64
#  8   transmission  51525 non-null  object
#  9   type          51525 non-null  object
#  10  paint_color   51525 non-null  object
#  11  is_4wd        51525 non-null  int64
#  12  date_posted   51525 non-null  datetime64[ns]
#  13  days_listed   51525 non-null  int64
#  14  year_posted   51525 non-null  int32
#  15  month_posted  51525 non-null  int32
#  16  day_posted    51525 non-null  int32
# dtypes: datetime64[ns](1), int32(3), int64(6), object(7)
# memory usage: 6.1+ MB

# %%
col = car_df.pop('days_listed')
car_df.insert(16, 'days_listed', col)
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   make          51525 non-null  object
#  3   model         51525 non-null  object
#  4   condition     51525 non-null  object
#  5   cylinders     51525 non-null  int64
#  6   fuel          51525 non-null  object
#  7   odometer      51525 non-null  int64
#  8   transmission  51525 non-null  object
#  9   type          51525 non-null  object
#  10  paint_color   51525 non-null  object
#  11  is_4wd        51525 non-null  int64
#  12  date_posted   51525 non-null  datetime64[ns]
#  13  year_posted   51525 non-null  int32
#  14  month_posted  51525 non-null  int32
#  15  day_posted    51525 non-null  int32
#  16  days_listed   51525 non-null  int64
# dtypes: datetime64[ns](1), int32(3), int64(6), object(7)
# memory usage: 6.1+ MB

# %% [markdown]
# ## EDA

# %%
car_df.sample(50)
# Out:
#        price  model_year        make                        model  condition  \
# 51489   1200        2005  volkswagen             volkswagen jetta       fair
# 11515   7700        2012       honda               honda civic lx  excellent
# 38991  15375        2017      toyota                 toyota camry   like new
# 30360  28995        2006         ram                     ram 3500       good
# 27230   5995        2008   chevrolet             chevrolet impala       good
# 19050   6000        2005   chevrolet     chevrolet silverado 1500       good
# 41432  23998        2015        jeep          jeep grand cherokee  excellent
# 20518  31000        2013         ram                     ram 2500  excellent
# 32371  35000        1972   chevrolet           chevrolet corvette  excellent
# 44193   3999        2006  volkswagen            volkswagen passat       good
# 14775   6200        2016      nissan                nissan sentra  excellent
# 2584   10995        2008        jeep                jeep wrangler  excellent
# 32961  22400        2015        jeep                jeep wrangler  excellent
# 33937  17995        2010   chevrolet   chevrolet silverado 2500hd  excellent
# 45396   7500        2007         bmw                       bmw x5       good
# 33586  10800        2013         ram                     ram 1500   like new
# 17897   8000        2009        jeep          jeep grand cherokee  excellent
# 12675   5707        2007        ford               ford fusion se  excellent
# 15573   5900        2013     hyundai              hyundai elantra   like new
# 3131    1650        2003        jeep   jeep grand cherokee laredo       fair
# 34439   6495        2005      toyota                 toyota camry  excellent
# 3592   16950        2018      nissan              nissan frontier   like new
# 32940   5495        2009       honda                 honda accord       good
# 5280    5000        2009      toyota                toyota tacoma       fair
# 46407  10500        2004         gmc              gmc sierra 1500  excellent
# 36651   3500        2005   chevrolet        chevrolet trailblazer   like new
# 45813   6500           1      toyota                 toyota prius  excellent
# 37347   3995        2007     hyundai             hyundai santa fe  excellent
# 7339    8200        2014      toyota                 toyota camry  excellent
# 9012    5700        2001        jeep                jeep wrangler  excellent
# 37492   3988           1        ford                   ford f-150       good
# 28078  25500        2013         ram                     ram 2500       good
# 45632  13495        2016         kia                     kia soul   like new
# 29608  26000        2017        ford                   ford f-150  excellent
# 3366    7800        2008   chevrolet          chevrolet silverado       good
# 49726  27500        2005         ram                     ram 3500  excellent
# 46976  21000        2018      nissan  nissan frontier crew cab sv       good
# 25692   1800        1998        ford                   ford f-150       fair
# 22442  11900           1         gmc                   gmc acadia  excellent
# 46247   2200        2003         ram                     ram 1500       good
# 38884   1500        2013   chevrolet              chevrolet tahoe   like new
# 9464       1        2018      nissan                 nissan rogue  excellent
# 19574   3999        2007    chrysler      chrysler town & country  excellent
# 24979   9900        2009         ram                     ram 1500   like new
# 37661  19995        2006         gmc            gmc sierra 2500hd       good
# 44107  10500        2007   chevrolet           chevrolet suburban   like new
# 7847   26500        2014        ford                   ford f-250       good
# 19116    287        2018   chevrolet             chevrolet impala   like new
# 18786   4000        2000        ford         ford f250 super duty       good
# 44948  10900        2007        jeep                jeep wrangler  excellent
#
#        cylinders    fuel  odometer transmission         type paint_color  \
# 51489          5     gas    185000    automatic        sedan        grey
# 11515          4     gas     94000    automatic        sedan       black
# 38991          4     gas     36500    automatic        sedan      silver
# 30360          6     gas    105532        other        truck         red
# 27230          6     gas    178750    automatic        sedan        grey
# 19050          8     gas    132000    automatic       pickup    unlisted
# 41432          8     gas        -1    automatic          SUV    unlisted
# 20518          6  diesel    127939    automatic       pickup    unlisted
# 32371          8     gas     50000       manual  convertible       white
# 44193          4     gas    144000    automatic        sedan       black
# 14775          4     gas    116231    automatic        sedan    unlisted
# 2584           6     gas    179176    automatic          SUV      silver
# 32961          6     gas        -1    automatic          SUV        blue
# 33937          8     gas        -1    automatic        truck         red
# 45396          6     gas        -1    automatic          SUV        blue
# 33586          6     gas    136000    automatic        truck       brown
# 17897          6     gas    124500    automatic          SUV      silver
# 12675          6     gas    152381    automatic        sedan      silver
# 15573          4     gas    120000    automatic        sedan    unlisted
# 3131           6     gas    228800    automatic          SUV       green
# 34439          6     gas     72173    automatic        sedan      silver
# 3592           6     gas        -1    automatic        truck       white
# 32940          4     gas        -1    automatic        coupe        grey
# 5280           4     gas    160000       manual        truck        grey
# 46407          8     gas    144321    automatic       pickup        grey
# 36651          6     gas    145365    automatic          SUV       green
# 45813          4  hybrid     80000    automatic        sedan       green
# 37347          6     gas    178000    automatic          SUV       brown
# 7339           4     gas    105457    automatic        coupe      silver
# 9012           4     gas    148883       manual          SUV         red
# 37492          8     gas    201400    automatic        truck        blue
# 28078          1     gas     83000    automatic        truck    unlisted
# 45632          4     gas     30000    automatic        wagon      silver
# 29608          1     gas        -1    automatic        truck         red
# 3366           8     gas    145000    automatic       pickup        blue
# 49726          6  diesel    102500       manual        truck      silver
# 46976          1     gas        -1        other       pickup      silver
# 25692          8     gas    216241    automatic        truck         red
# 22442          6     gas    104627    automatic          SUV       green
# 46247          8     gas    151000       manual        truck        blue
# 38884          8     gas    149000    automatic          SUV       white
# 9464          10     gas      6952        other          SUV        blue
# 19574          6     gas        -1    automatic          van       white
# 24979          8     gas    133000    automatic        truck      yellow
# 37661          8  diesel    145500    automatic       pickup       black
# 44107          8     gas    136000    automatic          SUV    unlisted
# 7847           8  diesel    136320    automatic       pickup       white
# 19116          1     gas        -1    automatic        sedan    unlisted
# 18786         10  diesel    257000    automatic        truck       white
# 44948          6     gas    105993       manual          SUV         red
#
#        is_4wd date_posted  year_posted  month_posted  day_posted  days_listed
# 51489       0  2018-10-10         2018            10          10          158
# 11515       0  2019-04-14         2019             4          14           14
# 38991       0  2018-11-23         2018            11          23           36
# 30360       1  2018-09-06         2018             9           6           58
# 27230       0  2018-08-04         2018             8           4           30
# 19050       1  2019-03-05         2019             3           5           25
# 41432       1  2019-01-21         2019             1          21           85
# 20518       1  2018-09-26         2018             9          26           34
# 32371       0  2019-03-21         2019             3          21           96
# 44193       0  2018-09-27         2018             9          27           89
# 14775       0  2018-05-16         2018             5          16           35
# 2584        1  2018-05-06         2018             5           6           23
# 32961       1  2019-03-27         2019             3          27           71
# 33937       1  2018-10-18         2018            10          18           25
# 45396       1  2018-06-10         2018             6          10            2
# 33586       0  2019-04-10         2019             4          10           37
# 17897       1  2018-09-26         2018             9          26           55
# 12675       1  2019-03-24         2019             3          24           96
# 15573       0  2018-10-25         2018            10          25           29
# 3131        1  2018-11-02         2018            11           2           22
# 34439       0  2018-09-19         2018             9          19           22
# 3592        0  2018-10-06         2018            10           6           14
# 32940       0  2018-10-11         2018            10          11            3
# 5280        0  2018-05-02         2018             5           2           20
# 46407       1  2018-07-02         2018             7           2           22
# 36651       1  2018-07-21         2018             7          21           33
# 45813       0  2018-11-19         2018            11          19           18
# 37347       0  2019-01-20         2019             1          20           31
# 7339        0  2019-04-17         2019             4          17           31
# 9012        1  2019-01-30         2019             1          30           66
# 37492       1  2018-06-20         2018             6          20           41
# 28078       1  2019-03-30         2019             3          30           41
# 45632       0  2018-05-09         2018             5           9           10
# 29608       1  2018-05-12         2018             5          12          125
# 3366        1  2018-11-30         2018            11          30           13
# 49726       1  2019-04-02         2019             4           2           69
# 46976       1  2018-07-07         2018             7           7           70
# 25692       1  2018-08-31         2018             8          31           31
# 22442       1  2018-10-21         2018            10          21           13
# 46247       1  2018-06-16         2018             6          16           43
# 38884       1  2019-02-17         2019             2          17           20
# 9464        1  2018-10-12         2018            10          12           26
# 19574       0  2018-05-20         2018             5          20           14
# 24979       1  2018-11-17         2018            11          17           60
# 37661       1  2018-10-23         2018            10          23           35
# 44107       1  2018-07-09         2018             7           9           89
# 7847        1  2019-01-31         2019             1          31           89
# 19116       0  2018-05-07         2018             5           7           16
# 18786       1  2018-12-21         2018            12          21           46
# 44948       1  2018-08-22         2018             8          22           62

# %%
model_year_group = car_df.groupby('model_year')
make_group = car_df.groupby('make')
model_group = car_df.groupby('model')
condition_group = car_df.groupby('condition')

# %%
model_year_agg = model_year_group['price'].agg(['count','sum','max','min','mean','std']).reset_index()
model_year_agg
# Out:
#     model_year  count       sum     max    min          mean           std
# 0            1   3619  42566009  109999      1  11761.815142   9465.731785
# 1         1908      2     25990   12995  12995  12995.000000      0.000000
# 2         1929      1     18000   18000  18000  18000.000000           NaN
# 3         1936      1      5000    5000   5000   5000.000000           NaN
# 4         1948      1     21000   21000  21000  21000.000000           NaN
# ..         ...    ...       ...     ...    ...           ...           ...
# 64        2015   3323  61143094  300000      1  18399.968101  10729.011701
# 65        2016   2954  57813498   76000      1  19571.258632  10408.650760
# 66        2017   2419  50163834   68000      1  20737.426209  10804.445977
# 67        2018   2193  53763964   90577      1  24516.171455  14970.534041
# 68        2019    380   9976589   84900      1  26254.181579  16482.045920
#
# [69 rows x 7 columns]

# %%
count_vs_model_year_old_fig = px.line(model_year_agg, x='model_year', y='count', range_x=[1908,1990], range_y=[0,60], title='Number of Listed Cars by Model Year, Before 1991')
count_vs_model_year_old_fig.show()

# %%
count_vs_model_year_new_fig = px.line(model_year_agg, x='model_year', y='count', range_x=[1991,2019], title='Number of Listed Cars by Model Year, After 1990')
count_vs_model_year_new_fig.show()

# %%
price_vs_model_year_fig = px.line(model_year_agg, x='model_year', y='mean', range_x=[1908,2019], error_y='std', title='Mean Listed Price by Model Year')
price_vs_model_year_fig.show()

# %%
old_car_df = car_df.loc[car_df['model_year'] < 1960]
muscle_car_df = car_df.loc[(car_df['model_year'] >= 1960) & (car_df['model_year'] < 1980)]
pre_new_car_df = car_df[(car_df['model_year'] >= 1980) & (car_df['model_year'] < 2000)]
new_car_df = car_df[car_df['model_year'] >= 2000]

# %%
old_car_group = old_car_df.groupby(['paint_color', 'make'])['model'].count().reset_index()
old_car_group.columns = ['paint_color', 'make', 'count']
old_car_group.sort_values(['paint_color', 'make'])
# Out:
#     paint_color       make  count
# 0         black      acura      6
# 1         black        bmw      3
# 2         black   cadillac      8
# 3         black  chevrolet    114
# 4         black   chrysler     10
# ..          ...        ...    ...
# 176      yellow       ford      6
# 177      yellow      honda      1
# 178      yellow    hyundai      1
# 179      yellow       jeep      4
# 180      yellow        ram      1
#
# [181 rows x 3 columns]

# %%
old_car_hist = px.bar(old_car_group, x='paint_color', y='count', color='make', title='Number of Cars of Each Color, 1900-1959')
old_car_hist.show()

# %%
old_car_scat = px.scatter(old_car_df.sort_values(['paint_color', 'make']), x='paint_color', y='price', color='make', title='Listed Price in USD vs Color, 1900-1959')
old_car_scat.show()

# %%
muscle_car_group = muscle_car_df.groupby(['paint_color', 'make'])['model'].count().reset_index()
muscle_car_group.columns = ['paint_color', 'make', 'count']
muscle_car_group.sort_values(['paint_color', 'make'])
muscle_car_hist = px.bar(muscle_car_group, x='paint_color', y='count', color='make', title='Number of Cars of Each Color, 1960-1979')
muscle_car_hist.show()

# %%
muscle_car_scat = px.scatter(muscle_car_df.sort_values(['paint_color', 'make']), x='paint_color', y='price', color='make', title='Listed Price in USD vs Color, 1960-1979')
muscle_car_scat.show()

# %%
pre_new_car_group = pre_new_car_df.groupby(['paint_color', 'make'])['model'].count().reset_index()
pre_new_car_group.columns = ['paint_color', 'make', 'count']
pre_new_car_group.sort_values(['paint_color', 'make'])
pre_new_car_hist = px.bar(pre_new_car_group, x='paint_color', y='count', color='make', title='Number of Cars of Each Color, 1980-1999')
pre_new_car_hist.show()

# %%
pre_new_car_scat = px.scatter(pre_new_car_df.sort_values(['paint_color', 'make']), x='paint_color', y='price', color='make', title='Listed Price in USD vs Color, 1980-1999')
pre_new_car_scat.show()

# %%
new_car_group = new_car_df.groupby(['paint_color', 'make'])['model'].count().reset_index()
new_car_group.columns = ['paint_color', 'make', 'count']
new_car_group.sort_values(['paint_color', 'make'])
new_car_hist = px.bar(new_car_group, x='paint_color', y='count', color='make', title='Number of Cars of Each Color, 2000-2019')
new_car_hist.show()

# %%
new_car_scat = px.scatter(new_car_df.sort_values(['paint_color', 'make']), x='paint_color', y='price', color='make', title='Listed Price in USD vs Color, 2000-2019')
new_car_scat.show()
